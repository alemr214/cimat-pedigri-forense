# %% [markdown]
# # 01. Exploración de los Datos

# %%
import numpy as np
import pandas as pd

# %%
db = pd.read_excel("../data/raw/archivo_combinado.xlsx")

# %%
# Split compund columns
db[['FAM_Sample_info_id', 'FAM_Sample_info_rel']] = db['FAM_Sample_info'].str.split(' ', n = 1, expand = True)

# %%
dbs
# Out:
#        FAM_Sample_info VIC_Sample_info  Shared_Markers  k0  k1  k2  \
# 0             012102 F        065402 F              15   0   4  11
# 1             023802 S        099602 F              15   0   7   8
# 2             047302 S        062402 F              15   0   6   9
# 3             116102 F        116702 F              15   0  10   5
# 4             122502 F        083702 S              15   0   8   7
# ...                ...             ...             ...  ..  ..  ..
# 879331        149701 U        149701 S              10   5   3   7
# 879332        149701 U        109202 U              10   5   4   6
# 879333        149801 U        149801 S              12   3   6   6
# 879334        150002 U        150002 S              11   4   5   6
# 879335        150002 U        080802 U              11   4   7   4
#
#         Share_allele     Value  True_positive  Marcadores     Software  \
# 0                 26  236354.0          False          15   BlindSeach
# 1                 23  184374.0          False          15   BlindSeach
# 2                 24   83900.6          False          15   BlindSeach
# 3                 20   41143.0          False          15   BlindSeach
# 4                 22   30327.8          False          15   BlindSeach
# ...              ...       ...            ...         ...          ...
# 879331            17       2.0           True          15  ScreenMatch
# 879332            16       1.0          False          15  ScreenMatch
# 879333            18       7.0           True          15  ScreenMatch
# 879334            17       3.0          False          15  ScreenMatch
# 879335            15       1.0          False          15  ScreenMatch
#
#             Datos     Kinship                                       File  \
# 0       Simulados  Paternidad  15_BlindSeach_Simulados_Paternidad_allele
# 1       Simulados  Paternidad  15_BlindSeach_Simulados_Paternidad_allele
# 2       Simulados  Paternidad  15_BlindSeach_Simulados_Paternidad_allele
# 3       Simulados  Paternidad  15_BlindSeach_Simulados_Paternidad_allele
# 4       Simulados  Paternidad  15_BlindSeach_Simulados_Paternidad_allele
# ...           ...         ...                                        ...
# 879331  Simulados   Hermandad  15_ScreenMatch_Simulados_Hermandad_allele
# 879332  Simulados   Hermandad  15_ScreenMatch_Simulados_Hermandad_allele
# 879333  Simulados   Hermandad  15_ScreenMatch_Simulados_Hermandad_allele
# 879334  Simulados   Hermandad  15_ScreenMatch_Simulados_Hermandad_allele
# 879335  Simulados   Hermandad  15_ScreenMatch_Simulados_Hermandad_allele
#
#                      Hoja    Sheet    Value_range FAM_Sample_info_id  \
# 0                   ipi-1    1:749  100000-999999             012102
# 1                   ipi-1    1:749  100000-999999             023802
# 2                   ipi-1    1:749    10000-99999             047302
# 3                   ipi-1    1:749    10000-99999             116102
# 4                   ipi-1    1:749    10000-99999             122502
# ...                   ...      ...            ...                ...
# 879331  Process_lisib-375  375:375           0-99             149701
# 879332  Process_lisib-375  375:375           0-99             149701
# 879333  Process_lisib-375  375:375           0-99             149801
# 879334  Process_lisib-375  375:375           0-99             150002
# 879335  Process_lisib-375  375:375           0-99             150002
#
#        FAM_Sample_info_rel
# 0                        F
# 1                        S
# 2                        S
# 3                        F
# 4                        F
# ...                    ...
# 879331                   U
# 879332                   U
# 879333                   U
# 879334                   U
# 879335                   U
#
# [879336 rows x 19 columns]
