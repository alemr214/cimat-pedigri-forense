# %% [markdown]
# # 02. Explore Train/Test Sets

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ## Read data

# %%
db = pd.read_csv("../data/processed/balanced/test.csv")
db
# Out:
#       Shared_Markers  k0  k1  k2  Share_allele      Value  True_positive  \
# 0                 13   2   8   5            18    3.01881          False
# 1                 13   2   7   6            19    3.42126          False
# 2                 13   2   5   8            21   30.00000          False
# 3                 10   5   3   7            17    2.00000          False
# 4                 12   3   6   6            18  200.00000          False
# ...              ...  ..  ..  ..           ...        ...            ...
# 5040              14   1   5   9            23   46.38480          False
# 5041              11   4   2   9            20   10.00000          False
# 5042              11   4   5   6            17    5.00000          False
# 5043              14   1   6   8            22    1.00000          False
# 5044              11   4   5   6            17    2.68561          False
#
#       Marcadores     Software      Datos     Kinship  \
# 0             15  BlindSearch  Simulados   Hermandad
# 1             15  BlindSearch  Simulados   Hermandad
# 2             15  ScreenMatch  Simulados   Hermandad
# 3             15  ScreenMatch  Simulados   Hermandad
# 4             15  ScreenMatch  Simulados   Hermandad
# ...          ...          ...        ...         ...
# 5040          15  BlindSearch  Simulados   Hermandad
# 5041          15  ScreenMatch  Simulados   Hermandad
# 5042          15  ScreenMatch  Simulados   Hermandad
# 5043          15  ScreenMatch  Simulados  Paternidad
# 5044          15  BlindSearch  Simulados   Hermandad
#
#                                             File               Hoja    Sheet  \
# 0      15_BlindSearch_Simulados_Hermandad_allele           isib-175  175:575
# 1      15_BlindSearch_Simulados_Hermandad_allele           isib-375  375:375
# 2      15_ScreenMatch_Simulados_Hermandad_allele    Process_LISIB-1    1:749
# 3      15_ScreenMatch_Simulados_Hermandad_allele  Process_lisib-375  375:375
# 4      15_ScreenMatch_Simulados_Hermandad_allele    Process_LISIB-1    1:749
# ...                                          ...                ...      ...
# 5040   15_BlindSearch_Simulados_Hermandad_allele             isib-1    1:749
# 5041   15_ScreenMatch_Simulados_Hermandad_allele    Process_LISIB-1    1:749
# 5042   15_ScreenMatch_Simulados_Hermandad_allele   Process_LISIB-97   97:653
# 5043  15_ScreenMatch_Simulados_Paternidad_allele     Process_LIPI-1    1:749
# 5044   15_BlindSearch_Simulados_Hermandad_allele             isib-1    1:749
#
#      Value_range  FAM_Sample_info_id FAM_Sample_info_rel  VIC_Sample_info_id  \
# 0           0-99               52302                   U               56701
# 1           0-99              106502                   U               69701
# 2           0-99               89702                   S              101402
# 3           0-99                4902                   S               64202
# 4        100-999               29302                   U              119202
# ...          ...                 ...                 ...                 ...
# 5040        0-99              101802                   U               12202
# 5041        0-99              101302                   S               30502
# 5042        0-99               97102                   U               64702
# 5043        0-99               47302                   S               48602
# 5044        0-99              129702                   U               21902
#
#      VIC_Sample_info_rel
# 0                      S
# 1                      U
# 2                      U
# 3                      S
# 4                      S
# ...                  ...
# 5040                   S
# 5041                   S
# 5042                   U
# 5043                   S
# 5044                   S
#
# [5045 rows x 19 columns]

# %%
db.FAM_Sample_info_id.apply(type).value_counts()
# Out:
# <class 'int'>    5045
# Name: FAM_Sample_info_id, dtype: int64

# %%
db[db.FAM_Sample_info_id.apply(type) == int]
# Out:
#       Shared_Markers  k0  k1  k2  Share_allele      Value  True_positive  \
# 0                 13   2   8   5            18    3.01881          False
# 1                 13   2   7   6            19    3.42126          False
# 2                 13   2   5   8            21   30.00000          False
# 3                 10   5   3   7            17    2.00000          False
# 4                 12   3   6   6            18  200.00000          False
# ...              ...  ..  ..  ..           ...        ...            ...
# 5040              14   1   5   9            23   46.38480          False
# 5041              11   4   2   9            20   10.00000          False
# 5042              11   4   5   6            17    5.00000          False
# 5043              14   1   6   8            22    1.00000          False
# 5044              11   4   5   6            17    2.68561          False
#
#       Marcadores     Software      Datos     Kinship  \
# 0             15  BlindSearch  Simulados   Hermandad
# 1             15  BlindSearch  Simulados   Hermandad
# 2             15  ScreenMatch  Simulados   Hermandad
# 3             15  ScreenMatch  Simulados   Hermandad
# 4             15  ScreenMatch  Simulados   Hermandad
# ...          ...          ...        ...         ...
# 5040          15  BlindSearch  Simulados   Hermandad
# 5041          15  ScreenMatch  Simulados   Hermandad
# 5042          15  ScreenMatch  Simulados   Hermandad
# 5043          15  ScreenMatch  Simulados  Paternidad
# 5044          15  BlindSearch  Simulados   Hermandad
#
#                                             File               Hoja    Sheet  \
# 0      15_BlindSearch_Simulados_Hermandad_allele           isib-175  175:575
# 1      15_BlindSearch_Simulados_Hermandad_allele           isib-375  375:375
# 2      15_ScreenMatch_Simulados_Hermandad_allele    Process_LISIB-1    1:749
# 3      15_ScreenMatch_Simulados_Hermandad_allele  Process_lisib-375  375:375
# 4      15_ScreenMatch_Simulados_Hermandad_allele    Process_LISIB-1    1:749
# ...                                          ...                ...      ...
# 5040   15_BlindSearch_Simulados_Hermandad_allele             isib-1    1:749
# 5041   15_ScreenMatch_Simulados_Hermandad_allele    Process_LISIB-1    1:749
# 5042   15_ScreenMatch_Simulados_Hermandad_allele   Process_LISIB-97   97:653
# 5043  15_ScreenMatch_Simulados_Paternidad_allele     Process_LIPI-1    1:749
# 5044   15_BlindSearch_Simulados_Hermandad_allele             isib-1    1:749
#
#      Value_range  FAM_Sample_info_id FAM_Sample_info_rel  VIC_Sample_info_id  \
# 0           0-99               52302                   U               56701
# 1           0-99              106502                   U               69701
# 2           0-99               89702                   S              101402
# 3           0-99                4902                   S               64202
# 4        100-999               29302                   U              119202
# ...          ...                 ...                 ...                 ...
# 5040        0-99              101802                   U               12202
# 5041        0-99              101302                   S               30502
# 5042        0-99               97102                   U               64702
# 5043        0-99               47302                   S               48602
# 5044        0-99              129702                   U               21902
#
#      VIC_Sample_info_rel
# 0                      S
# 1                      U
# 2                      U
# 3                      S
# 4                      S
# ...                  ...
# 5040                   S
# 5041                   S
# 5042                   U
# 5043                   S
# 5044                   S
#
# [5045 rows x 19 columns]

# %% [markdown]
# ## Comprobar si Existen Registros Contradictorios

# %%
a = db[["Shared_Markers", "k0", "k1", "k2", "Share_allele", "True_positive"]].copy()
a = a.groupby(["Shared_Markers", "k0", "k1", "k2", "Share_allele"]).size().reset_index()

b = db[["Shared_Markers", "k0", "k1", "k2", "Share_allele", "True_positive"]].copy()
b = b.groupby(["Shared_Markers", "k0", "k1", "k2", "Share_allele"]).sum().reset_index()

# %%
result = pd.merge(a, b, on=["Shared_Markers", "k0", "k1", "k2", "Share_allele"], how='inner')
result.rename(columns = {0: 'count', 'True_positive': 'positives'}, inplace= True)

# %%
# Definir una función para crear la nueva columna
def calc_discrepancy(row):
  if row['positives'] == row['count']:
    return 0
  else:
    return min(row['positives'],
               row['count'] - row['positives'])

# Aplicar la función a cada fila
result['discrepancy'] = result.apply(calc_discrepancy, axis=1)
result
# Out:
#     Shared_Markers  k0  k1  k2  Share_allele  count  positives  discrepancy
# 0                8   7   0   8            16      1          0            0
# 1                8   7   1   7            15      1          0            0
# 2                8   7   2   6            14      1          0            0
# 3                8   7   3   5            13      2          0            0
# 4                9   6   1   8            17      8          0            0
# ..             ...  ..  ..  ..           ...    ...        ...          ...
# 65              15   0   9   6            21     30          4            4
# 66              15   0  10   5            20     19          2            2
# 67              15   0  11   4            19      9          1            1
# 68              15   0  12   3            18      4          0            0
# 69              15   0  13   2            17      3          0            0
#
# [70 rows x 8 columns]

# %%
result["discrepancy"].hist()
plt.title("Cantidad de labels que difieren de la mayoría")
plt.xlabel("Cantidad de labels diferentes")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
print(f"En total existen {sum(result['discrepancy'])} discrepancias en los datos.")
# Out:
# En total existen 53 discrepancias en los datos.

# %% [markdown]
# ### Mostrar un Ejemplo de Registros Contradictorios

# %%
db[(db.k0 == 0) & (db.k1 == 8) & (db.k2 == 7)]
# Out:
#       Shared_Markers  k0  k1  k2  Share_allele         Value  True_positive  \
# 129               15   0   8   7            22  6.853090e+01          False
# 852               15   0   8   7            22  2.278500e+03          False
# 1006              15   0   8   7            22  2.000000e+01          False
# 1025              15   0   8   7            22  3.833960e+00          False
# 1345              15   0   8   7            22  5.617870e+05           True
# 1356              15   0   8   7            22  3.000000e+02          False
# 1521              15   0   8   7            22  5.000000e+03           True
# 1613              15   0   8   7            22  6.783020e+01          False
# 1826              15   0   8   7            22  4.475700e+04           True
# 2029              15   0   8   7            22  5.000000e+02          False
# 2630              15   0   8   7            22  3.000000e+01          False
# 2910              15   0   8   7            22  2.197810e+06           True
# 3045              15   0   8   7            22  7.000000e+01          False
# 3103              15   0   8   7            22  1.288010e+00          False
# 3330              15   0   8   7            22  8.212980e+00          False
# 3563              15   0   8   7            22  1.546430e+03          False
# 3754              15   0   8   7            22  2.000000e+05           True
# 3833              15   0   8   7            22  3.151690e+02          False
# 3860              15   0   8   7            22  9.000000e+01          False
# 3865              15   0   8   7            22  5.000000e+03           True
# 3913              15   0   8   7            22  1.479420e+01          False
# 3947              15   0   8   7            22  1.596590e+01          False
# 3960              15   0   8   7            22  4.776960e+02          False
# 4063              15   0   8   7            22  2.000000e+04           True
# 4094              15   0   8   7            22  2.032550e+03          False
# 4345              15   0   8   7            22  4.000000e+03           True
# 4420              15   0   8   7            22  1.153720e+02          False
# 4432              15   0   8   7            22  3.148680e+03          False
# 4466              15   0   8   7            22  4.373880e+07           True
# 4515              15   0   8   7            22  8.000000e+02          False
#
#       Marcadores     Software      Datos     Kinship  \
# 129           15   BlindSeach  Simulados  Paternidad
# 852           15   BlindSeach  Simulados  Paternidad
# 1006          15  ScreenMatch  Simulados   Hermandad
# 1025          15  BlindSearch  Simulados   Hermandad
# 1345          15   BlindSeach  Simulados  Paternidad
# 1356          15  ScreenMatch  Simulados  Paternidad
# 1521          15  ScreenMatch  Simulados  Paternidad
# 1613          15   BlindSeach  Simulados  Paternidad
# 1826          15   BlindSeach  Simulados  Paternidad
# 2029          15  ScreenMatch  Simulados  Paternidad
# 2630          15  ScreenMatch  Simulados   Hermandad
# 2910          15   BlindSeach  Simulados  Paternidad
# 3045          15  ScreenMatch  Simulados  Paternidad
# 3103          15  BlindSearch  Simulados   Hermandad
# 3330          15  BlindSearch  Simulados   Hermandad
# 3563          15   BlindSeach  Simulados  Paternidad
# 3754          15  ScreenMatch  Simulados  Paternidad
# 3833          15   BlindSeach  Simulados  Paternidad
# 3860          15  ScreenMatch  Simulados   Hermandad
# 3865          15  ScreenMatch  Simulados  Paternidad
# 3913          15  BlindSearch  Simulados   Hermandad
# 3947          15  BlindSearch  Simulados   Hermandad
# 3960          15   BlindSeach  Simulados  Paternidad
# 4063          15  ScreenMatch  Simulados  Paternidad
# 4094          15   BlindSeach  Simulados  Paternidad
# 4345          15  ScreenMatch  Simulados  Paternidad
# 4420          15  BlindSearch  Simulados   Hermandad
# 4432          15   BlindSeach  Simulados  Paternidad
# 4466          15   BlindSeach  Simulados  Paternidad
# 4515          15  ScreenMatch  Simulados  Paternidad
#
#                                             File               Hoja    Sheet  \
# 129    15_BlindSeach_Simulados_Paternidad_allele              ipi-1    1:749
# 852    15_BlindSeach_Simulados_Paternidad_allele            ipi-175  175:575
# 1006   15_ScreenMatch_Simulados_Hermandad_allele    Process_LISIB-1    1:749
# 1025   15_BlindSearch_Simulados_Hermandad_allele            isib-60   60:690
# 1345   15_BlindSeach_Simulados_Paternidad_allele             ipi-97   97:653
# 1356  15_ScreenMatch_Simulados_Paternidad_allele     Process_LIPI-1    1:749
# 1521  15_ScreenMatch_Simulados_Paternidad_allele   Process_LIPI-175  175:575
# 1613   15_BlindSeach_Simulados_Paternidad_allele              ipi-1    1:749
# 1826   15_BlindSeach_Simulados_Paternidad_allele            ipi-375  375:375
# 2029  15_ScreenMatch_Simulados_Paternidad_allele     Process_LIPI-7    7:743
# 2630   15_ScreenMatch_Simulados_Hermandad_allele  Process_lisib-375  375:375
# 2910   15_BlindSeach_Simulados_Paternidad_allele             ipi-60   60:690
# 3045  15_ScreenMatch_Simulados_Paternidad_allele     Process_LIPI-1    1:749
# 3103   15_BlindSearch_Simulados_Hermandad_allele             isib-1    1:749
# 3330   15_BlindSearch_Simulados_Hermandad_allele             isib-1    1:749
# 3563   15_BlindSeach_Simulados_Paternidad_allele              ipi-1    1:749
# 3754  15_ScreenMatch_Simulados_Paternidad_allele    Process_LIPI-30   30:720
# 3833   15_BlindSeach_Simulados_Paternidad_allele              ipi-1    1:749
# 3860   15_ScreenMatch_Simulados_Hermandad_allele  Process_lisib-375  375:375
# 3865  15_ScreenMatch_Simulados_Paternidad_allele   Process_LIPI-175  175:575
# 3913   15_BlindSearch_Simulados_Hermandad_allele           isib-375  375:375
# 3947   15_BlindSearch_Simulados_Hermandad_allele             isib-1    1:749
# 3960   15_BlindSeach_Simulados_Paternidad_allele              ipi-7    7:743
# 4063  15_ScreenMatch_Simulados_Paternidad_allele   Process_LIPI-375  375:375
# 4094   15_BlindSeach_Simulados_Paternidad_allele              ipi-1    1:749
# 4345  15_ScreenMatch_Simulados_Paternidad_allele   Process_LIPI-375  375:375
# 4420   15_BlindSearch_Simulados_Hermandad_allele           isib-375  375:375
# 4432   15_BlindSeach_Simulados_Paternidad_allele            ipi-375  375:375
# 4466   15_BlindSeach_Simulados_Paternidad_allele            ipi-175  175:575
# 4515  15_ScreenMatch_Simulados_Paternidad_allele   Process_LIPI-375  375:375
#
#         Value_range  FAM_Sample_info_id FAM_Sample_info_rel  \
# 129            0-99              107702                   S
# 852       1000-9999               43201                   S
# 1006           0-99               45402                   S
# 1025           0-99              126201                   S
# 1345  100000-999999              102801                   S
# 1356        100-999               32302                   F
# 1521      1000-9999               20401                   S
# 1613           0-99              105302                   S
# 1826    10000-99999              106601                   S
# 2029        100-999               95702                   S
# 2630           0-99               91302                   S
# 2910       1000000+              128201                   S
# 3045           0-99              148402                   F
# 3103           0-99               70402                   U
# 3330           0-99              101302                   U
# 3563      1000-9999              111702                   S
# 3754  100000-999999              118801                   S
# 3833        100-999              121202                   S
# 3860           0-99              101401                   S
# 3865      1000-9999               33801                   S
# 3913           0-99              133002                   U
# 3947           0-99               85402                   S
# 3960        100-999              147101                   F
# 4063    10000-99999              149101                   S
# 4094      1000-9999                4202                   S
# 4345      1000-9999               51101                   F
# 4420        100-999               27401                   S
# 4432      1000-9999              136601                   F
# 4466       1000000+               67101                   S
# 4515        100-999               16801                   F
#
#       VIC_Sample_info_id VIC_Sample_info_rel
# 129                 6302                   S
# 852                99302                   S
# 1006              126502                   S
# 1025               88602                   U
# 1345              102801                   F
# 1356               54002                   S
# 1521               20401                   F
# 1613               93302                   F
# 1826              106601                   F
# 2029              147101                   F
# 2630              142301                   S
# 2910              128201                   F
# 3045               93302                   F
# 3103               84602                   S
# 3330               39002                   U
# 3563              120002                   S
# 3754              118801                   F
# 3833               64802                   S
# 3860              146501                   U
# 3865               33801                   F
# 3913              135501                   U
# 3947               90902                   U
# 3960               95702                   S
# 4063              149101                   F
# 4094               50102                   F
# 4345               51101                   S
# 4420               78801                   U
# 4432               91101                   F
# 4466               67101                   F
# 4515              117202                   F
